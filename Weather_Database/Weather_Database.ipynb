# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 735

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Descrition": city_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | songjianghe
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | sao joao da barra
# Processing Record 5 of Set 1 | aklavik
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | waingapu
# Processing Record 8 of Set 1 | vila do maio
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | lasa
# Processing Record 12 of Set 1 | jamestown
# Processing Record 13 of Set 1 | amurzet
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | port alfred
# Processing Record 16 of Set 1 | saint-philippe
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | portland
# Processing Record 19 of Set 1 | ust-tsilma
# Processing Record 20 of Set 1 | adrar
# Processing Record 21 of Set 1 | puerto ayora
# Processing Record 22 of Set 1 | chabahar
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | saint-georges
# Processing Record 25 of Set 1 | severo-kurilsk
# Processing Record 26 of Set 1 | ashta
# Processing Record 27 of Set 1 | cape town
# Processing Record 28 of Set 1 | hermanus
# Processing Record 29 of Set 1 | saldanha
# Processing Record 30 of Set 1 | san juan
# Processing Record 31 of Set 1 | tiksi
# Processing Record 32 of Set 1 | bluff
# Processing Record 33 of Set 1 | kahului
# Processing Record 34 of Set 1 | norman wells
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | paranaiba
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | litovko
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | ayan
# Processing Record 41 of Set 1 | alice springs
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | mount gambier
# Processing Record 44 of Set 1 | san carlos de bariloche
# Processing Record 45 of Set 1 | shafter
# Processing Record 46 of Set 1 | porbandar
# Processing Record 47 of Set 1 | rabo de peixe
# Processing Record 48 of Set 1 | palmeira das missoes
# Processing Record 49 of Set 1 | castro
# Processing Record 50 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 1 of Set 2 | hobart
# Processing Record 2 of Set 2 | serrinha
# Processing Record 3 of Set 2 | mopti
# Processing Record 4 of Set 2 | nikolskoye
# Processing Record 5 of Set 2 | awjilah
# Processing Record 6 of Set 2 | faya
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 10 of Set 2 | nuuk
# Processing Record 11 of Set 2 | sabzevar
# Processing Record 12 of Set 2 | quatre cocos
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | axim
# Processing Record 15 of Set 2 | punta arenas
# Processing Record 16 of Set 2 | rondonopolis
# Processing Record 17 of Set 2 | hay river
# Processing Record 18 of Set 2 | mwingi
# Processing Record 19 of Set 2 | la ronge
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | bengkulu
# Processing Record 23 of Set 2 | khorixas
# Processing Record 24 of Set 2 | dabola
# Processing Record 25 of Set 2 | ribeira grande
# Processing Record 26 of Set 2 | savantvadi
# Processing Record 27 of Set 2 | broome
# Processing Record 28 of Set 2 | inirida
# Processing Record 29 of Set 2 | weligama
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | vila franca do campo
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | dikson
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | derazhnya
# Processing Record 36 of Set 2 | zavetnoye
# Processing Record 37 of Set 2 | poum
# Processing Record 38 of Set 2 | wajir
# Processing Record 39 of Set 2 | isangel
# Processing Record 40 of Set 2 | nguiu
# City not found. Skipping...
# Processing Record 41 of Set 2 | los llanos de aridane
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | aasiaat
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 2 | ahuimanu
# Processing Record 47 of Set 2 | diu
# Processing Record 48 of Set 2 | abakaliki
# Processing Record 49 of Set 2 | atuona
# Processing Record 50 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 3 | honningsvag
# Processing Record 2 of Set 3 | barrow
# Processing Record 3 of Set 3 | lebu
# Processing Record 4 of Set 3 | svetlogorsk
# Processing Record 5 of Set 3 | talakan
# Processing Record 6 of Set 3 | urucui
# Processing Record 7 of Set 3 | uk
# City not found. Skipping...
# Processing Record 8 of Set 3 | ancud
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | racine
# Processing Record 11 of Set 3 | burica
# City not found. Skipping...
# Processing Record 12 of Set 3 | yellowknife
# Processing Record 13 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 14 of Set 3 | east london
# Processing Record 15 of Set 3 | tynda
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | saint george
# Processing Record 18 of Set 3 | roma
# Processing Record 19 of Set 3 | sarangani
# Processing Record 20 of Set 3 | fortuna
# Processing Record 21 of Set 3 | bambous virieux
# Processing Record 22 of Set 3 | batagay-alyta
# Processing Record 23 of Set 3 | rocha
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | hobyo
# Processing Record 26 of Set 3 | bud
# Processing Record 27 of Set 3 | cayambe
# Processing Record 28 of Set 3 | prince rupert
# Processing Record 29 of Set 3 | manchester
# Processing Record 30 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 3 | sabang
# Processing Record 32 of Set 3 | redding
# Processing Record 33 of Set 3 | gizo
# Processing Record 34 of Set 3 | souillac
# Processing Record 35 of Set 3 | zambezi
# Processing Record 36 of Set 3 | muyezerskiy
# Processing Record 37 of Set 3 | doka
# Processing Record 38 of Set 3 | lavrentiya
# Processing Record 39 of Set 3 | georgetown
# Processing Record 40 of Set 3 | kapaa
# Processing Record 41 of Set 3 | ahipara
# Processing Record 42 of Set 3 | diego de almagro
# Processing Record 43 of Set 3 | longyearbyen
# Processing Record 44 of Set 3 | bokoro
# Processing Record 45 of Set 3 | oblivskaya
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | chapais
# Processing Record 48 of Set 3 | ilulissat
# Processing Record 49 of Set 3 | quelimane
# Processing Record 50 of Set 3 | constitucion
# Processing Record 1 of Set 4 | oriximina
# Processing Record 2 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 3 of Set 4 | auxerre
# Processing Record 4 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 5 of Set 4 | penha
# Processing Record 6 of Set 4 | henties bay
# Processing Record 7 of Set 4 | lensk
# Processing Record 8 of Set 4 | tasiilaq
# Processing Record 9 of Set 4 | santa fe
# Processing Record 10 of Set 4 | tuktoyaktuk
# Processing Record 11 of Set 4 | esso
# Processing Record 12 of Set 4 | murray bridge
# Processing Record 13 of Set 4 | odweyne
# Processing Record 14 of Set 4 | mayumba
# Processing Record 15 of Set 4 | xining
# Processing Record 16 of Set 4 | victoria
# Processing Record 17 of Set 4 | eureka
# Processing Record 18 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 4 | farmington
# Processing Record 20 of Set 4 | tashtagol
# Processing Record 21 of Set 4 | kasongo-lunda
# Processing Record 22 of Set 4 | cherskiy
# Processing Record 23 of Set 4 | marienburg
# Processing Record 24 of Set 4 | iquitos
# Processing Record 25 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 4 | san patricio
# Processing Record 27 of Set 4 | zyryanka
# Processing Record 28 of Set 4 | el oro
# Processing Record 29 of Set 4 | iskateley
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | bouna
# Processing Record 33 of Set 4 | deer lake
# Processing Record 34 of Set 4 | hearst
# Processing Record 35 of Set 4 | dalby
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 4 | macenta
# Processing Record 39 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 4 | surgut
# Processing Record 41 of Set 4 | kaitangata
# Processing Record 42 of Set 4 | dingle
# Processing Record 43 of Set 4 | oktyabrskoye
# Processing Record 44 of Set 4 | mastic beach
# Processing Record 45 of Set 4 | tautira
# Processing Record 46 of Set 4 | eyl
# Processing Record 47 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 4 | laguna
# Processing Record 49 of Set 4 | dolores
# Processing Record 50 of Set 4 | olafsvik
# Processing Record 1 of Set 5 | asau
# Processing Record 2 of Set 5 | cabo san lucas
# Processing Record 3 of Set 5 | hofn
# Processing Record 4 of Set 5 | obihiro
# Processing Record 5 of Set 5 | pochutla
# Processing Record 6 of Set 5 | komsomolskiy
# Processing Record 7 of Set 5 | capiibary
# Processing Record 8 of Set 5 | vila
# Processing Record 9 of Set 5 | puerto madryn
# Processing Record 10 of Set 5 | kyaukse
# Processing Record 11 of Set 5 | ban nahin
# Processing Record 12 of Set 5 | braganca
# Processing Record 13 of Set 5 | kurilsk
# Processing Record 14 of Set 5 | yerbogachen
# Processing Record 15 of Set 5 | kysyl-syr
# Processing Record 16 of Set 5 | yaan
# Processing Record 17 of Set 5 | erenhot
# Processing Record 18 of Set 5 | geraldton
# Processing Record 19 of Set 5 | karagay
# Processing Record 20 of Set 5 | tual
# Processing Record 21 of Set 5 | itupiranga
# Processing Record 22 of Set 5 | ternuvate
# Processing Record 23 of Set 5 | mabaruma
# Processing Record 24 of Set 5 | russell
# Processing Record 25 of Set 5 | irbil
# Processing Record 26 of Set 5 | kachikau
# City not found. Skipping...
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | ardabil
# Processing Record 29 of Set 5 | lyaskelya
# Processing Record 30 of Set 5 | te anau
# Processing Record 31 of Set 5 | pachino
# Processing Record 32 of Set 5 | luba
# Processing Record 33 of Set 5 | brae
# Processing Record 34 of Set 5 | tatarsk
# Processing Record 35 of Set 5 | ponta do sol
# Processing Record 36 of Set 5 | port-cartier
# Processing Record 37 of Set 5 | cabatuan
# Processing Record 38 of Set 5 | forio
# Processing Record 39 of Set 5 | shingu
# Processing Record 40 of Set 5 | talnakh
# Processing Record 41 of Set 5 | suntar
# Processing Record 42 of Set 5 | lagoa
# Processing Record 43 of Set 5 | oak ridge
# Processing Record 44 of Set 5 | megion
# Processing Record 45 of Set 5 | lorengau
# Processing Record 46 of Set 5 | wahiawa
# Processing Record 47 of Set 5 | naze
# Processing Record 48 of Set 5 | saint anthony
# Processing Record 49 of Set 5 | nouadhibou
# Processing Record 50 of Set 5 | elk city
# Processing Record 1 of Set 6 | tura
# Processing Record 2 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 6 | ampanihy
# Processing Record 4 of Set 6 | hawwarah
# City not found. Skipping...
# Processing Record 5 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 6 of Set 6 | kilindoni
# Processing Record 7 of Set 6 | cedar city
# Processing Record 8 of Set 6 | port hedland
# Processing Record 9 of Set 6 | namatanai
# Processing Record 10 of Set 6 | primo tapia
# Processing Record 11 of Set 6 | sitka
# Processing Record 12 of Set 6 | ulladulla
# Processing Record 13 of Set 6 | esperance
# Processing Record 14 of Set 6 | nome
# Processing Record 15 of Set 6 | ushtobe
# Processing Record 16 of Set 6 | tezu
# Processing Record 17 of Set 6 | mahanoro
# Processing Record 18 of Set 6 | grand gaube
# Processing Record 19 of Set 6 | gobabis
# Processing Record 20 of Set 6 | inndyr
# Processing Record 21 of Set 6 | caravelas
# Processing Record 22 of Set 6 | balkhash
# Processing Record 23 of Set 6 | noumea
# Processing Record 24 of Set 6 | port hardy
# Processing Record 25 of Set 6 | tuatapere
# Processing Record 26 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 27 of Set 6 | vanimo
# Processing Record 28 of Set 6 | todos santos
# Processing Record 29 of Set 6 | carballo
# Processing Record 30 of Set 6 | pangody
# Processing Record 31 of Set 6 | waipawa
# Processing Record 32 of Set 6 | chimbote
# Processing Record 33 of Set 6 | meadow lake
# Processing Record 34 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 6 | garden city
# Processing Record 36 of Set 6 | buchanan
# Processing Record 37 of Set 6 | pimentel
# Processing Record 38 of Set 6 | aroysund
# Processing Record 39 of Set 6 | bima
# Processing Record 40 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 41 of Set 6 | hoshcha
# Processing Record 42 of Set 6 | kibala
# Processing Record 43 of Set 6 | teguldet
# Processing Record 44 of Set 6 | kreminna
# Processing Record 45 of Set 6 | vao
# Processing Record 46 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 47 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 48 of Set 6 | lichinga
# Processing Record 49 of Set 6 | badou
# Processing Record 50 of Set 6 | buala
# Processing Record 1 of Set 7 | flin flon
# Processing Record 2 of Set 7 | sakassou
# Processing Record 3 of Set 7 | sainte-rose
# Processing Record 4 of Set 7 | pemba
# Processing Record 5 of Set 7 | chinhoyi
# Processing Record 6 of Set 7 | santa isabel do rio negro
# Processing Record 7 of Set 7 | jalu
# Processing Record 8 of Set 7 | alpena
# Processing Record 9 of Set 7 | wum
# Processing Record 10 of Set 7 | mount isa
# Processing Record 11 of Set 7 | kabanjahe
# Processing Record 12 of Set 7 | north bend
# Processing Record 13 of Set 7 | saint-pierre
# Processing Record 14 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 15 of Set 7 | saku
# Processing Record 16 of Set 7 | kuytun
# Processing Record 17 of Set 7 | seydi
# Processing Record 18 of Set 7 | ciudad bolivar
# Processing Record 19 of Set 7 | yakeshi
# Processing Record 20 of Set 7 | mamallapuram
# Processing Record 21 of Set 7 | burnie
# Processing Record 22 of Set 7 | jizan
# Processing Record 23 of Set 7 | pevek
# Processing Record 24 of Set 7 | pitimbu
# Processing Record 25 of Set 7 | mantua
# Processing Record 26 of Set 7 | kalmunai
# Processing Record 27 of Set 7 | nantucket
# Processing Record 28 of Set 7 | lermontovka
# Processing Record 29 of Set 7 | vurnary
# Processing Record 30 of Set 7 | mineiros
# Processing Record 31 of Set 7 | port-gentil
# Processing Record 32 of Set 7 | daura
# Processing Record 33 of Set 7 | alta gracia
# Processing Record 34 of Set 7 | cyangugu
# Processing Record 35 of Set 7 | half moon bay
# Processing Record 36 of Set 7 | bandar-e lengeh
# Processing Record 37 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 7 | chokurdakh
# Processing Record 39 of Set 7 | tiznit
# Processing Record 40 of Set 7 | saint-augustin
# Processing Record 41 of Set 7 | nam som
# Processing Record 42 of Set 7 | puerto carreno
# Processing Record 43 of Set 7 | clyde river
# Processing Record 44 of Set 7 | dalvik
# Processing Record 45 of Set 7 | ust-nera
# Processing Record 46 of Set 7 | darhan
# Processing Record 47 of Set 7 | big rapids
# Processing Record 48 of Set 7 | lata
# Processing Record 49 of Set 7 | denpasar
# Processing Record 50 of Set 7 | slobidka
# Processing Record 1 of Set 8 | anadyr
# Processing Record 2 of Set 8 | manjeshwar
# Processing Record 3 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 8 | formosa do rio preto
# Processing Record 5 of Set 8 | atherton
# Processing Record 6 of Set 8 | salalah
# Processing Record 7 of Set 8 | bacungan
# Processing Record 8 of Set 8 | raga
# Processing Record 9 of Set 8 | antagan
# City not found. Skipping...
# Processing Record 10 of Set 8 | cockburn town
# Processing Record 11 of Set 8 | bull savanna
# Processing Record 12 of Set 8 | ipixuna
# Processing Record 13 of Set 8 | play cu
# City not found. Skipping...
# Processing Record 14 of Set 8 | the valley
# Processing Record 15 of Set 8 | avera
# Processing Record 16 of Set 8 | tateyama
# Processing Record 17 of Set 8 | portobelo
# Processing Record 18 of Set 8 | guilin
# Processing Record 19 of Set 8 | hambantota
# Processing Record 20 of Set 8 | cocobeach
# Processing Record 21 of Set 8 | koumac
# Processing Record 22 of Set 8 | kartuzy
# Processing Record 23 of Set 8 | phumi samraong
# City not found. Skipping...
# Processing Record 24 of Set 8 | jiaohe
# Processing Record 25 of Set 8 | luderitz
# Processing Record 26 of Set 8 | tabasco
# Processing Record 27 of Set 8 | winslow
# Processing Record 28 of Set 8 | sembakung
# Processing Record 29 of Set 8 | cabrero
# Processing Record 30 of Set 8 | nemuro
# Processing Record 31 of Set 8 | zhigansk
# Processing Record 32 of Set 8 | almaznyy
# Processing Record 33 of Set 8 | auki
# Processing Record 34 of Set 8 | codrington
# Processing Record 35 of Set 8 | kiyasovo
# Processing Record 36 of Set 8 | vardo
# Processing Record 37 of Set 8 | ambilobe
# Processing Record 38 of Set 8 | roald
# Processing Record 39 of Set 8 | airai
# Processing Record 40 of Set 8 | ixtapa
# Processing Record 41 of Set 8 | say
# Processing Record 42 of Set 8 | shaunavon
# Processing Record 43 of Set 8 | rokytne
# Processing Record 44 of Set 8 | lengshuijiang
# Processing Record 45 of Set 8 | gurskoye
# City not found. Skipping...
# Processing Record 46 of Set 8 | high rock
# Processing Record 47 of Set 8 | smoky lake
# Processing Record 48 of Set 8 | jaguarari
# Processing Record 49 of Set 8 | hamilton
# Processing Record 50 of Set 8 | vila velha
# Processing Record 1 of Set 9 | adamantina
# Processing Record 2 of Set 9 | hithadhoo
# Processing Record 3 of Set 9 | sept-iles
# Processing Record 4 of Set 9 | tomari
# Processing Record 5 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 6 of Set 9 | coihaique
# Processing Record 7 of Set 9 | port moresby
# Processing Record 8 of Set 9 | cap-aux-meules
# Processing Record 9 of Set 9 | bokspits
# City not found. Skipping...
# Processing Record 10 of Set 9 | emerald
# Processing Record 11 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 12 of Set 9 | karpogory
# Processing Record 13 of Set 9 | liaozhong
# Processing Record 14 of Set 9 | kudahuvadhoo
# Processing Record 15 of Set 9 | soyo
# Processing Record 16 of Set 9 | high level
# Processing Record 17 of Set 9 | hasaki
# Processing Record 18 of Set 9 | george town
# Processing Record 19 of Set 9 | bathsheba
# Processing Record 20 of Set 9 | chiredzi
# Processing Record 21 of Set 9 | fare
# Processing Record 22 of Set 9 | nadym
# Processing Record 23 of Set 9 | saint-francois
# Processing Record 24 of Set 9 | esterhazy
# Processing Record 25 of Set 9 | tilichiki
# Processing Record 26 of Set 9 | port blair
# Processing Record 27 of Set 9 | shirvan
# Processing Record 28 of Set 9 | zhezkazgan
# Processing Record 29 of Set 9 | villazon
# Processing Record 30 of Set 9 | marsa matruh
# Processing Record 31 of Set 9 | aita mare
# Processing Record 32 of Set 9 | okhotsk
# Processing Record 33 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 34 of Set 9 | ambon
# Processing Record 35 of Set 9 | tsienyane
# City not found. Skipping...
# Processing Record 36 of Set 9 | mahebourg
# Processing Record 37 of Set 9 | taitung
# Processing Record 38 of Set 9 | godo
# Processing Record 39 of Set 9 | amatitan
# Processing Record 40 of Set 9 | labuhan
# Processing Record 41 of Set 9 | verkhovazhye
# Processing Record 42 of Set 9 | arkhipo-osipovka
# Processing Record 43 of Set 9 | westport
# Processing Record 44 of Set 9 | sola
# Processing Record 45 of Set 9 | sioux lookout
# Processing Record 46 of Set 9 | college
# Processing Record 47 of Set 9 | ouesso
# Processing Record 48 of Set 9 | beringovskiy
# Processing Record 49 of Set 9 | mareeba
# Processing Record 50 of Set 9 | manzanillo
# Processing Record 1 of Set 10 | havoysund
# Processing Record 2 of Set 10 | arkhangelsk
# Processing Record 3 of Set 10 | aketi
# Processing Record 4 of Set 10 | klaksvik
# Processing Record 5 of Set 10 | guerrero negro
# Processing Record 6 of Set 10 | suhbaatar
# Processing Record 7 of Set 10 | gra liyia
# Processing Record 8 of Set 10 | chahal
# Processing Record 9 of Set 10 | sao filipe
# Processing Record 10 of Set 10 | hovd
# Processing Record 11 of Set 10 | baykit
# Processing Record 12 of Set 10 | bubaque
# Processing Record 13 of Set 10 | yangjiang
# Processing Record 14 of Set 10 | rio grande
# Processing Record 15 of Set 10 | lake havasu city
# Processing Record 16 of Set 10 | fillan
# Processing Record 17 of Set 10 | calabar
# Processing Record 18 of Set 10 | chuy
# Processing Record 19 of Set 10 | felidhoo
# City not found. Skipping...
# Processing Record 20 of Set 10 | novikovo
# Processing Record 21 of Set 10 | pacific grove
# Processing Record 22 of Set 10 | camana
# Processing Record 23 of Set 10 | cuamba
# Processing Record 24 of Set 10 | clarence town
# Processing Record 25 of Set 10 | fairview
# Processing Record 26 of Set 10 | boshnyakovo
# Processing Record 27 of Set 10 | qarqin
# Processing Record 28 of Set 10 | plettenberg bay
# Processing Record 29 of Set 10 | nouakchott
# Processing Record 30 of Set 10 | boden
# Processing Record 31 of Set 10 | pilar
# Processing Record 32 of Set 10 | namtsy
# Processing Record 33 of Set 10 | illapel
# Processing Record 34 of Set 10 | iquique
# Processing Record 35 of Set 10 | torbay
# Processing Record 36 of Set 10 | gamba
# Processing Record 37 of Set 10 | grand-lahou
# Processing Record 38 of Set 10 | wamba
# Processing Record 39 of Set 10 | benguela
# Processing Record 40 of Set 10 | lethem
# Processing Record 41 of Set 10 | san pedro de macoris
# Processing Record 42 of Set 10 | husavik
# Processing Record 43 of Set 10 | wanning
# Processing Record 44 of Set 10 | kangaatsiaq
# Processing Record 45 of Set 10 | taoudenni
# Processing Record 46 of Set 10 | pizarro
# Processing Record 47 of Set 10 | aswan
# Processing Record 48 of Set 10 | katete
# Processing Record 49 of Set 10 | merauke
# Processing Record 50 of Set 10 | kloulklubed
# Processing Record 1 of Set 11 | wrzesnia
# Processing Record 2 of Set 11 | mayo
# Processing Record 3 of Set 11 | hervey bay
# Processing Record 4 of Set 11 | houma
# Processing Record 5 of Set 11 | mangrol
# Processing Record 6 of Set 11 | manutuke
# Processing Record 7 of Set 11 | japura
# Processing Record 8 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 10 of Set 11 | itarema
# Processing Record 11 of Set 11 | palmer
# Processing Record 12 of Set 11 | altamira
# Processing Record 13 of Set 11 | omboue
# Processing Record 14 of Set 11 | nyagan
# Processing Record 15 of Set 11 | lompoc
# Processing Record 16 of Set 11 | alihe
# Processing Record 17 of Set 11 | harper
# Processing Record 18 of Set 11 | kushmurun
# Processing Record 19 of Set 11 | san-pedro
# Processing Record 20 of Set 11 | broken hill
# Processing Record 21 of Set 11 | dundee
# Processing Record 22 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 23 of Set 11 | la palma
# Processing Record 24 of Set 11 | tessalit
# Processing Record 25 of Set 11 | menongue
# Processing Record 26 of Set 11 | havre-saint-pierre
# Processing Record 27 of Set 11 | cayenne
# Processing Record 28 of Set 11 | pisco
# Processing Record 29 of Set 11 | narsaq
# Processing Record 30 of Set 11 | kupino
# Processing Record 31 of Set 11 | egvekinot
# Processing Record 32 of Set 11 | arlit
# Processing Record 33 of Set 11 | oranjemund
# Processing Record 34 of Set 11 | abnub
# Processing Record 35 of Set 11 | vung tau
# Processing Record 36 of Set 11 | penhold
# Processing Record 37 of Set 11 | ngunguru
# Processing Record 38 of Set 11 | uthal
# Processing Record 39 of Set 11 | brasilia
# Processing Record 40 of Set 11 | sheboygan
# Processing Record 41 of Set 11 | mnogovershinnyy
# Processing Record 42 of Set 11 | katsuura
# Processing Record 43 of Set 11 | marakkanam
# Processing Record 44 of Set 11 | nelipyno
# Processing Record 45 of Set 11 | amancio
# City not found. Skipping...
# Processing Record 46 of Set 11 | karamea
# City not found. Skipping...
# Processing Record 47 of Set 11 | mananara
# Processing Record 48 of Set 11 | mentok
# City not found. Skipping...
# Processing Record 49 of Set 11 | ambulu
# Processing Record 50 of Set 11 | carahue
# Processing Record 1 of Set 12 | lazaro cardenas
# Processing Record 2 of Set 12 | port augusta
# Processing Record 3 of Set 12 | gazojak
# Processing Record 4 of Set 12 | dabeiba
# Processing Record 5 of Set 12 | pangnirtung
# Processing Record 6 of Set 12 | mazarron
# Processing Record 7 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 8 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 9 of Set 12 | san cristobal
# Processing Record 10 of Set 12 | camacha
# Processing Record 11 of Set 12 | doha
# Processing Record 12 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 12 | benjamin constant
# Processing Record 14 of Set 12 | shymkent
# Processing Record 15 of Set 12 | melfi
# Processing Record 16 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 12 | ocean city
# Processing Record 18 of Set 12 | big bend
# Processing Record 19 of Set 12 | praia da vitoria
# Processing Record 20 of Set 12 | kapit
# Processing Record 21 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 22 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 12 | qaqortoq
# Processing Record 24 of Set 12 | kieta
# Processing Record 25 of Set 12 | alta floresta
# Processing Record 26 of Set 12 | kushima
# Processing Record 27 of Set 12 | itaituba
# Processing Record 28 of Set 12 | mayor pablo lagerenza
# Processing Record 29 of Set 12 | vostok
# Processing Record 30 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 31 of Set 12 | smithers
# Processing Record 32 of Set 12 | gemena
# Processing Record 33 of Set 12 | jalingo
# Processing Record 34 of Set 12 | sao paulo de olivenca
# Processing Record 35 of Set 12 | sisimiut
# Processing Record 36 of Set 12 | batagay
# Processing Record 37 of Set 12 | maldonado
# Processing Record 38 of Set 12 | banjar
# Processing Record 39 of Set 12 | oyon
# Processing Record 40 of Set 12 | geilo
# Processing Record 41 of Set 12 | poso
# Processing Record 42 of Set 12 | de-kastri
# Processing Record 43 of Set 12 | maceio
# Processing Record 44 of Set 12 | whitianga
# Processing Record 45 of Set 12 | necochea
# Processing Record 46 of Set 12 | khilok
# Processing Record 47 of Set 12 | barra do corda
# Processing Record 48 of Set 12 | urengoy
# Processing Record 49 of Set 12 | kasulu
# Processing Record 50 of Set 12 | deep river
# Processing Record 1 of Set 13 | kaeo
# Processing Record 2 of Set 13 | verkhnebakanskiy
# Processing Record 3 of Set 13 | along
# Processing Record 4 of Set 13 | weyburn
# Processing Record 5 of Set 13 | maraa
# Processing Record 6 of Set 13 | sao felix do xingu
# Processing Record 7 of Set 13 | parker
# Processing Record 8 of Set 13 | kathu
# Processing Record 9 of Set 13 | porto velho
# Processing Record 10 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 11 of Set 13 | birao
# Processing Record 12 of Set 13 | myshkin
# Processing Record 13 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 14 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 13 | stawell
# Processing Record 16 of Set 13 | roseau
# Processing Record 17 of Set 13 | belyy yar
# Processing Record 18 of Set 13 | antonina
# Processing Record 19 of Set 13 | marzuq
# Processing Record 20 of Set 13 | xapuri
# Processing Record 21 of Set 13 | barao de melgaco
# Processing Record 22 of Set 13 | charlestown
# Processing Record 23 of Set 13 | isla aguada
# Processing Record 24 of Set 13 | bantry
# Processing Record 25 of Set 13 | takoradi
# Processing Record 26 of Set 13 | suluktu
# Processing Record 27 of Set 13 | kamaishi
# Processing Record 28 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 29 of Set 13 | chulumani
# Processing Record 30 of Set 13 | coquimbo
# Processing Record 31 of Set 13 | san jose
# Processing Record 32 of Set 13 | saint simons
# Processing Record 33 of Set 13 | sorland
# Processing Record 34 of Set 13 | arari
# Processing Record 35 of Set 13 | caxito
# Processing Record 36 of Set 13 | kanniyakumari
# Processing Record 37 of Set 13 | kruisfontein
# Processing Record 38 of Set 13 | viedma
# Processing Record 39 of Set 13 | santa cruz de la palma
# Processing Record 40 of Set 13 | aripuana
# Processing Record 41 of Set 13 | south river
# Processing Record 42 of Set 13 | iqaluit
# Processing Record 43 of Set 13 | almaty
# Processing Record 44 of Set 13 | riyadh
# Processing Record 45 of Set 13 | greensburg
# Processing Record 46 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 13 | novo oriente
# Processing Record 48 of Set 13 | wazzan
# City not found. Skipping...
# Processing Record 49 of Set 13 | bontang
# Processing Record 50 of Set 13 | abiy adi
# City not found. Skipping...
# Processing Record 1 of Set 14 | gurupi
# Processing Record 2 of Set 14 | bogalusa
# Processing Record 3 of Set 14 | geresk
# City not found. Skipping...
# Processing Record 4 of Set 14 | dubbo
# Processing Record 5 of Set 14 | chihuahua
# Processing Record 6 of Set 14 | muros
# Processing Record 7 of Set 14 | kostek
# Processing Record 8 of Set 14 | grindavik
# Processing Record 9 of Set 14 | kologriv
# Processing Record 10 of Set 14 | sao jose da coroa grande
# Processing Record 11 of Set 14 | salinas
# Processing Record 12 of Set 14 | atambua
# Processing Record 13 of Set 14 | samarai
# Processing Record 14 of Set 14 | sharanga
# Processing Record 15 of Set 14 | barcelos
# Processing Record 16 of Set 14 | changde
# Processing Record 17 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 14 | grootfontein
# Processing Record 19 of Set 14 | kulhudhuffushi
# Processing Record 20 of Set 14 | lakselv
# Processing Record 21 of Set 14 | toamasina
# Processing Record 22 of Set 14 | macau
# Processing Record 23 of Set 14 | lagos
# Processing Record 24 of Set 14 | bilaspur
# Processing Record 25 of Set 14 | marawi
# Processing Record 26 of Set 14 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 14 | nanortalik
# Processing Record 28 of Set 14 | leshukonskoye
# Processing Record 29 of Set 14 | najran
# Processing Record 30 of Set 14 | yining
# Processing Record 31 of Set 14 | xuddur
# Processing Record 32 of Set 14 | morehead
# Processing Record 33 of Set 14 | sangar
# Processing Record 34 of Set 14 | adre
# Processing Record 35 of Set 14 | krasnoselkup
# Processing Record 36 of Set 14 | lavumisa
# Processing Record 37 of Set 14 | mapiripan
# Processing Record 38 of Set 14 | saint-joseph
# Processing Record 39 of Set 14 | oudtshoorn
# Processing Record 40 of Set 14 | fairbanks
# Processing Record 41 of Set 14 | punuare
# Processing Record 42 of Set 14 | dawei
# Processing Record 43 of Set 14 | whyalla
# Processing Record 44 of Set 14 | cheyenne
# Processing Record 45 of Set 14 | zyryanskoye
# Processing Record 46 of Set 14 | belmonte
# Processing Record 47 of Set 14 | wattegama
# Processing Record 48 of Set 14 | kendari
# Processing Record 49 of Set 14 | manyana
# Processing Record 50 of Set 14 | anaconda
# Processing Record 1 of Set 15 | angoram
# Processing Record 2 of Set 15 | vallenar
# Processing Record 3 of Set 15 | bowen
# Processing Record 4 of Set 15 | marshall
# Processing Record 5 of Set 15 | balabac
# Processing Record 6 of Set 15 | nibbar
# Processing Record 7 of Set 15 | anar darreh
# City not found. Skipping...
# Processing Record 8 of Set 15 | tirano
# Processing Record 9 of Set 15 | ketchikan
# Processing Record 10 of Set 15 | boulder
# Processing Record 11 of Set 15 | thinadhoo
# Processing Record 12 of Set 15 | tecpan
# Processing Record 13 of Set 15 | orlik
# Processing Record 14 of Set 15 | kolno
# Processing Record 15 of Set 15 | grande-riviere
# City not found. Skipping...
# Processing Record 16 of Set 15 | upington
# Processing Record 17 of Set 15 | sohbatpur
# Processing Record 18 of Set 15 | bekhtery
# Processing Record 19 of Set 15 | nileshwar
# Processing Record 20 of Set 15 | balaipungut
# Processing Record 21 of Set 15 | aktas
# Processing Record 22 of Set 15 | vanavara
# Processing Record 23 of Set 15 | glen avon
# Processing Record 24 of Set 15 | udachnyy
# Processing Record 25 of Set 15 | korcula
# Processing Record 26 of Set 15 | jijiga
# Processing Record 27 of Set 15 | powell river
# Processing Record 28 of Set 15 | erice
# Processing Record 29 of Set 15 | belaya gora
# Processing Record 30 of Set 15 | amuntai
# Processing Record 31 of Set 15 | bambanglipuro
# Processing Record 32 of Set 15 | mango
# Processing Record 33 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 34 of Set 15 | san quintin
# Processing Record 35 of Set 15 | mogadishu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng Current Descrition  Max Temp  \
# 0            Rikitea -23.1203 -134.9692          clear sky     70.74
# 1        Songjianghe  42.1859  127.4790    overcast clouds     72.72
# 2             Avarua -21.2078 -159.7750      broken clouds     77.05
# 3  Sao Joao Da Barra -21.6403  -41.0511         few clouds     69.82
# 4            Aklavik  68.2191 -135.0107    overcast clouds     50.83
# 5             Kodiak  57.7900 -152.4072    overcast clouds     54.93
# 6           Waingapu  -9.6567  120.2641          clear sky     87.21
# 7       Vila Do Maio  15.1333  -23.2167    overcast clouds     77.79
# 8              Vaini -21.2000 -175.2000    overcast clouds     68.16
# 9          Upernavik  72.7868  -56.1549    overcast clouds     44.29
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        67           2       13.91      PF
# 1        74          94        3.56      CN
# 2        78          75        2.30      CK
# 3        88          12       15.61      BR
# 4        81         100        3.47      CA
# 5        78         100        1.23      US
# 6        55           6       16.49      ID
# 7        76          99        8.90      CV
# 8        77          90       10.36      TO
# 9        77         100        6.26      GL

# %%
new_column_order = ["City" , "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed",  "Current Descrition"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0            Rikitea      PF -23.1203 -134.9692     70.74        67
# 1        Songjianghe      CN  42.1859  127.4790     72.72        74
# 2             Avarua      CK -21.2078 -159.7750     77.05        78
# 3  Sao Joao Da Barra      BR -21.6403  -41.0511     69.82        88
# 4            Aklavik      CA  68.2191 -135.0107     50.83        81
# 5             Kodiak      US  57.7900 -152.4072     54.93        78
# 6           Waingapu      ID  -9.6567  120.2641     87.21        55
# 7       Vila Do Maio      CV  15.1333  -23.2167     77.79        76
# 8              Vaini      TO -21.2000 -175.2000     68.16        77
# 9          Upernavik      GL  72.7868  -56.1549     44.29        77
#
#    Cloudiness  Wind Speed Current Descrition
# 0           2       13.91          clear sky
# 1          94        3.56    overcast clouds
# 2          75        2.30      broken clouds
# 3          12       15.61         few clouds
# 4         100        3.47    overcast clouds
# 5         100        1.23    overcast clouds
# 6           6       16.49          clear sky
# 7          99        8.90    overcast clouds
# 8          90       10.36    overcast clouds
# 9         100        6.26    overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/weatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
