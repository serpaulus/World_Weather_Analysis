# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_desc = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Descrition": city_desc,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | albany
# Processing Record 2 of Set 1 | norman wells
# Processing Record 3 of Set 1 | clyde river
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | praya
# Processing Record 6 of Set 1 | mtsensk
# Processing Record 7 of Set 1 | urumqi
# Processing Record 8 of Set 1 | lagoa
# Processing Record 9 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | nikolskoye
# Processing Record 12 of Set 1 | fomboni
# Processing Record 13 of Set 1 | airai
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | pacific grove
# Processing Record 16 of Set 1 | tadine
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | port hardy
# Processing Record 19 of Set 1 | chute-aux-outardes
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of Set 1 | carballo
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | tiksi
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | magole
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | mandera
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | hobart
# Processing Record 33 of Set 1 | kapoeta
# Processing Record 34 of Set 1 | severo-kurilsk
# Processing Record 35 of Set 1 | saldanha
# Processing Record 36 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 37 of Set 1 | lompoc
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | olafsvik
# Processing Record 40 of Set 1 | panama city
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | tasiilaq
# Processing Record 43 of Set 1 | eureka
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 1 | dunedin
# Processing Record 48 of Set 1 | aklavik
# Processing Record 49 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 1 | biltine
# Processing Record 1 of Set 2 | geraldton
# Processing Record 2 of Set 2 | fukue
# Processing Record 3 of Set 2 | coquimbo
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | porto walter
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | aykhal
# Processing Record 8 of Set 2 | kruisfontein
# Processing Record 9 of Set 2 | lebu
# Processing Record 10 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 11 of Set 2 | dauphin
# Processing Record 12 of Set 2 | miguel hidalgo
# Processing Record 13 of Set 2 | berdigestyakh
# Processing Record 14 of Set 2 | bodden town
# Processing Record 15 of Set 2 | massakory
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | ostersund
# Processing Record 19 of Set 2 | paciran
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | tiarei
# Processing Record 22 of Set 2 | saint george
# Processing Record 23 of Set 2 | provideniya
# Processing Record 24 of Set 2 | kavieng
# Processing Record 25 of Set 2 | waycross
# Processing Record 26 of Set 2 | freeport
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | ribeira grande
# Processing Record 29 of Set 2 | isla vista
# Processing Record 30 of Set 2 | ayan
# Processing Record 31 of Set 2 | beloha
# Processing Record 32 of Set 2 | rosarito
# Processing Record 33 of Set 2 | vaini
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | kodiak
# Processing Record 36 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 2 | mount gambier
# Processing Record 40 of Set 2 | cabedelo
# Processing Record 41 of Set 2 | bathsheba
# Processing Record 42 of Set 2 | sao filipe
# Processing Record 43 of Set 2 | kiruna
# Processing Record 44 of Set 2 | elat
# Processing Record 45 of Set 2 | sorland
# Processing Record 46 of Set 2 | hirara
# Processing Record 47 of Set 2 | dapaong
# Processing Record 48 of Set 2 | ahipara
# Processing Record 49 of Set 2 | emerald
# Processing Record 50 of Set 2 | bereda
# Processing Record 1 of Set 3 | meadow lake
# Processing Record 2 of Set 3 | lensk
# Processing Record 3 of Set 3 | new norfolk
# Processing Record 4 of Set 3 | gweta
# Processing Record 5 of Set 3 | neiafu
# Processing Record 6 of Set 3 | larap
# Processing Record 7 of Set 3 | salalah
# Processing Record 8 of Set 3 | punta arenas
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | amilly
# Processing Record 11 of Set 3 | thompson
# Processing Record 12 of Set 3 | visnes
# Processing Record 13 of Set 3 | namuac
# Processing Record 14 of Set 3 | tautira
# Processing Record 15 of Set 3 | acapulco
# Processing Record 16 of Set 3 | belyy yar
# Processing Record 17 of Set 3 | nam tha
# City not found. Skipping...
# Processing Record 18 of Set 3 | celestun
# Processing Record 19 of Set 3 | cabo san lucas
# Processing Record 20 of Set 3 | vestmanna
# Processing Record 21 of Set 3 | torbay
# Processing Record 22 of Set 3 | asau
# Processing Record 23 of Set 3 | alice springs
# Processing Record 24 of Set 3 | severodvinsk
# Processing Record 25 of Set 3 | qaanaaq
# Processing Record 26 of Set 3 | kachiry
# Processing Record 27 of Set 3 | bayeux
# Processing Record 28 of Set 3 | marawi
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | batemans bay
# Processing Record 31 of Set 3 | hithadhoo
# Processing Record 32 of Set 3 | minot
# Processing Record 33 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 3 | banga
# Processing Record 35 of Set 3 | pevek
# Processing Record 36 of Set 3 | butaritari
# Processing Record 37 of Set 3 | saint-philippe
# Processing Record 38 of Set 3 | kapaa
# Processing Record 39 of Set 3 | guerrero negro
# Processing Record 40 of Set 3 | dongsheng
# Processing Record 41 of Set 3 | dingle
# Processing Record 42 of Set 3 | carnarvon
# Processing Record 43 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 45 of Set 3 | bambous virieux
# Processing Record 46 of Set 3 | da nang
# Processing Record 47 of Set 3 | oranjemund
# Processing Record 48 of Set 3 | barguzin
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | portland
# Processing Record 2 of Set 4 | reconquista
# Processing Record 3 of Set 4 | rawson
# Processing Record 4 of Set 4 | alyangula
# Processing Record 5 of Set 4 | tawang
# Processing Record 6 of Set 4 | san rafael del sur
# Processing Record 7 of Set 4 | taoudenni
# Processing Record 8 of Set 4 | sovetskiy
# Processing Record 9 of Set 4 | vila franca do campo
# Processing Record 10 of Set 4 | mocuba
# Processing Record 11 of Set 4 | portree
# Processing Record 12 of Set 4 | atar
# Processing Record 13 of Set 4 | tairua
# Processing Record 14 of Set 4 | cockburn town
# Processing Record 15 of Set 4 | castro
# Processing Record 16 of Set 4 | hervey bay
# Processing Record 17 of Set 4 | saint-augustin
# Processing Record 18 of Set 4 | kaitangata
# Processing Record 19 of Set 4 | lephepe
# City not found. Skipping...
# Processing Record 20 of Set 4 | arlit
# Processing Record 21 of Set 4 | tura
# Processing Record 22 of Set 4 | virginia beach
# Processing Record 23 of Set 4 | lamar
# Processing Record 24 of Set 4 | natal
# Processing Record 25 of Set 4 | adrar
# Processing Record 26 of Set 4 | nogales
# Processing Record 27 of Set 4 | nouadhibou
# Processing Record 28 of Set 4 | kargasok
# Processing Record 29 of Set 4 | avera
# Processing Record 30 of Set 4 | plettenberg bay
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | rocky mountain house
# Processing Record 33 of Set 4 | saskylakh
# Processing Record 34 of Set 4 | kahului
# Processing Record 35 of Set 4 | bengkulu
# Processing Record 36 of Set 4 | hami
# Processing Record 37 of Set 4 | lorengau
# Processing Record 38 of Set 4 | kuching
# Processing Record 39 of Set 4 | khatanga
# Processing Record 40 of Set 4 | logrono
# Processing Record 41 of Set 4 | upernavik
# Processing Record 42 of Set 4 | poronaysk
# Processing Record 43 of Set 4 | chapais
# Processing Record 44 of Set 4 | namibe
# Processing Record 45 of Set 4 | panuco
# Processing Record 46 of Set 4 | vestmannaeyjar
# Processing Record 47 of Set 4 | kitoy
# Processing Record 48 of Set 4 | chebsara
# Processing Record 49 of Set 4 | sterling
# Processing Record 50 of Set 4 | haljala
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | jumla
# Processing Record 3 of Set 5 | muroto
# Processing Record 4 of Set 5 | usinsk
# Processing Record 5 of Set 5 | makakilo city
# Processing Record 6 of Set 5 | darnah
# Processing Record 7 of Set 5 | kailua
# Processing Record 8 of Set 5 | batagay
# Processing Record 9 of Set 5 | yingshang
# City not found. Skipping...
# Processing Record 10 of Set 5 | leningradskiy
# Processing Record 11 of Set 5 | netarhat
# Processing Record 12 of Set 5 | kazanskaya
# Processing Record 13 of Set 5 | cherskiy
# Processing Record 14 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 15 of Set 5 | boljarovo
# City not found. Skipping...
# Processing Record 16 of Set 5 | choma
# Processing Record 17 of Set 5 | prattville
# Processing Record 18 of Set 5 | shibata
# Processing Record 19 of Set 5 | esperance
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | umm lajj
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | ambon
# Processing Record 24 of Set 5 | jalu
# Processing Record 25 of Set 5 | poum
# Processing Record 26 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 5 | oussouye
# Processing Record 28 of Set 5 | olkhovka
# Processing Record 29 of Set 5 | san antonio
# Processing Record 30 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 31 of Set 5 | fairbanks
# Processing Record 32 of Set 5 | maxixe
# Processing Record 33 of Set 5 | victoria
# Processing Record 34 of Set 5 | wenatchee
# Processing Record 35 of Set 5 | takoradi
# Processing Record 36 of Set 5 | lavrentiya
# Processing Record 37 of Set 5 | husavik
# Processing Record 38 of Set 5 | kenai
# Processing Record 39 of Set 5 | mayo
# Processing Record 40 of Set 5 | paka
# Processing Record 41 of Set 5 | mahebourg
# Processing Record 42 of Set 5 | zhigansk
# Processing Record 43 of Set 5 | sinnamary
# Processing Record 44 of Set 5 | bahia blanca
# Processing Record 45 of Set 5 | port jervis
# Processing Record 46 of Set 5 | alexandria
# Processing Record 47 of Set 5 | haines junction
# Processing Record 48 of Set 5 | amahai
# Processing Record 49 of Set 5 | hasaki
# Processing Record 50 of Set 5 | port elizabeth
# Processing Record 1 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 6 | krasnoselkup
# Processing Record 3 of Set 6 | luderitz
# Processing Record 4 of Set 6 | nautla
# Processing Record 5 of Set 6 | la palma
# Processing Record 6 of Set 6 | banda aceh
# Processing Record 7 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 6 | broken hill
# Processing Record 9 of Set 6 | sao jose da coroa grande
# Processing Record 10 of Set 6 | paamiut
# Processing Record 11 of Set 6 | nishihara
# Processing Record 12 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 6 | nagaur
# Processing Record 14 of Set 6 | turukhansk
# Processing Record 15 of Set 6 | katsuura
# Processing Record 16 of Set 6 | isangel
# Processing Record 17 of Set 6 | russell
# Processing Record 18 of Set 6 | skrunda
# Processing Record 19 of Set 6 | oudtshoorn
# Processing Record 20 of Set 6 | winnemucca
# Processing Record 21 of Set 6 | sola
# Processing Record 22 of Set 6 | santa maria
# Processing Record 23 of Set 6 | tindwari
# Processing Record 24 of Set 6 | wuchi
# Processing Record 25 of Set 6 | dao
# Processing Record 26 of Set 6 | kedrovyy
# Processing Record 27 of Set 6 | fortuna
# Processing Record 28 of Set 6 | san patricio
# Processing Record 29 of Set 6 | west wendover
# Processing Record 30 of Set 6 | ixtapa
# Processing Record 31 of Set 6 | tateyama
# Processing Record 32 of Set 6 | prado
# Processing Record 33 of Set 6 | keshod
# Processing Record 34 of Set 6 | luau
# Processing Record 35 of Set 6 | nuuk
# Processing Record 36 of Set 6 | surt
# Processing Record 37 of Set 6 | bom jardim
# Processing Record 38 of Set 6 | linhares
# Processing Record 39 of Set 6 | manicore
# Processing Record 40 of Set 6 | porto tolle
# Processing Record 41 of Set 6 | severnyy
# Processing Record 42 of Set 6 | lerwick
# Processing Record 43 of Set 6 | humaita
# Processing Record 44 of Set 6 | doha
# Processing Record 45 of Set 6 | ha tinh
# Processing Record 46 of Set 6 | vila velha
# Processing Record 47 of Set 6 | bosaso
# Processing Record 48 of Set 6 | bakel
# Processing Record 49 of Set 6 | la asuncion
# Processing Record 50 of Set 6 | byron bay
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | slave lake
# Processing Record 3 of Set 7 | ust-nera
# Processing Record 4 of Set 7 | tokur
# Processing Record 5 of Set 7 | verkhoyansk
# Processing Record 6 of Set 7 | yeppoon
# Processing Record 7 of Set 7 | tlalchapa
# Processing Record 8 of Set 7 | vrangel
# Processing Record 9 of Set 7 | grand gaube
# Processing Record 10 of Set 7 | voyvozh
# Processing Record 11 of Set 7 | karratha
# Processing Record 12 of Set 7 | hambantota
# Processing Record 13 of Set 7 | shimoda
# Processing Record 14 of Set 7 | cayenne
# Processing Record 15 of Set 7 | strezhevoy
# Processing Record 16 of Set 7 | eldorado
# Processing Record 17 of Set 7 | vardo
# Processing Record 18 of Set 7 | baturaja
# Processing Record 19 of Set 7 | broome
# Processing Record 20 of Set 7 | jalalabad
# Processing Record 21 of Set 7 | faya
# Processing Record 22 of Set 7 | auki
# Processing Record 23 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 7 | neuenkirchen
# Processing Record 25 of Set 7 | qui nhon
# Processing Record 26 of Set 7 | santiago del estero
# Processing Record 27 of Set 7 | mounana
# Processing Record 28 of Set 7 | padang
# Processing Record 29 of Set 7 | hamilton
# Processing Record 30 of Set 7 | buraydah
# Processing Record 31 of Set 7 | cacador
# Processing Record 32 of Set 7 | codrington
# Processing Record 33 of Set 7 | labytnangi
# Processing Record 34 of Set 7 | imaichi
# Processing Record 35 of Set 7 | axim
# Processing Record 36 of Set 7 | klaksvik
# Processing Record 37 of Set 7 | te anau
# Processing Record 38 of Set 7 | qandala
# Processing Record 39 of Set 7 | marzuq
# Processing Record 40 of Set 7 | pangkalanbuun
# Processing Record 41 of Set 7 | luanda
# Processing Record 42 of Set 7 | abu dhabi
# Processing Record 43 of Set 7 | khani
# Processing Record 44 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 7 | omboue
# Processing Record 46 of Set 7 | richards bay
# Processing Record 47 of Set 7 | dinsor
# City not found. Skipping...
# Processing Record 48 of Set 7 | durban
# Processing Record 49 of Set 7 | haapu
# City not found. Skipping...
# Processing Record 50 of Set 7 | sfantu gheorghe
# Processing Record 1 of Set 8 | vila
# Processing Record 2 of Set 8 | tahta
# Processing Record 3 of Set 8 | tiznit
# Processing Record 4 of Set 8 | imbituba
# Processing Record 5 of Set 8 | nicolas bravo
# Processing Record 6 of Set 8 | batticaloa
# Processing Record 7 of Set 8 | miranorte
# City not found. Skipping...
# Processing Record 8 of Set 8 | nunoa
# Processing Record 9 of Set 8 | kaniama
# Processing Record 10 of Set 8 | cortes
# Processing Record 11 of Set 8 | talnakh
# Processing Record 12 of Set 8 | san juan
# Processing Record 13 of Set 8 | kamyshevatskaya
# Processing Record 14 of Set 8 | magaria
# Processing Record 15 of Set 8 | champerico
# Processing Record 16 of Set 8 | maniitsoq
# Processing Record 17 of Set 8 | puerto colombia
# Processing Record 18 of Set 8 | olinda
# Processing Record 19 of Set 8 | kazanskoye
# Processing Record 20 of Set 8 | eyl
# Processing Record 21 of Set 8 | alta floresta
# Processing Record 22 of Set 8 | dehloran
# Processing Record 23 of Set 8 | pisco
# Processing Record 24 of Set 8 | gravatai
# Processing Record 25 of Set 8 | potrerillos
# Processing Record 26 of Set 8 | empangeni
# Processing Record 27 of Set 8 | harper
# Processing Record 28 of Set 8 | cap malheureux
# Processing Record 29 of Set 8 | sendafa
# Processing Record 30 of Set 8 | belgrade
# Processing Record 31 of Set 8 | abu jubayhah
# City not found. Skipping...
# Processing Record 32 of Set 8 | gigmoto
# Processing Record 33 of Set 8 | margate
# Processing Record 34 of Set 8 | ushtobe
# Processing Record 35 of Set 8 | todos santos
# Processing Record 36 of Set 8 | bandarbeyla
# Processing Record 37 of Set 8 | oksfjord
# Processing Record 38 of Set 8 | akureyri
# Processing Record 39 of Set 8 | anshan
# Processing Record 40 of Set 8 | miri
# Processing Record 41 of Set 8 | kudahuvadhoo
# Processing Record 42 of Set 8 | huarmey
# Processing Record 43 of Set 8 | salinas
# Processing Record 44 of Set 8 | palmer
# Processing Record 45 of Set 8 | hobyo
# Processing Record 46 of Set 8 | zalantun
# Processing Record 47 of Set 8 | port blair
# Processing Record 48 of Set 8 | rosetta
# Processing Record 49 of Set 8 | mayskiy
# Processing Record 50 of Set 8 | port hedland
# Processing Record 1 of Set 9 | qaqortoq
# Processing Record 2 of Set 9 | vyyezdnoye
# Processing Record 3 of Set 9 | constitucion
# Processing Record 4 of Set 9 | san carlos del zulia
# Processing Record 5 of Set 9 | lat yao
# Processing Record 6 of Set 9 | lethem
# Processing Record 7 of Set 9 | naliya
# Processing Record 8 of Set 9 | sitka
# Processing Record 9 of Set 9 | sydney mines
# Processing Record 10 of Set 9 | mandalgovi
# Processing Record 11 of Set 9 | orocue
# Processing Record 12 of Set 9 | anaco
# Processing Record 13 of Set 9 | cuamba
# Processing Record 14 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 9 | asfi
# Processing Record 16 of Set 9 | gimli
# Processing Record 17 of Set 9 | awbari
# Processing Record 18 of Set 9 | rosiile
# Processing Record 19 of Set 9 | lasa
# Processing Record 20 of Set 9 | sioux lookout
# Processing Record 21 of Set 9 | ahumada
# City not found. Skipping...
# Processing Record 22 of Set 9 | narsaq
# Processing Record 23 of Set 9 | muborak
# Processing Record 24 of Set 9 | alofi
# Processing Record 25 of Set 9 | ginir
# Processing Record 26 of Set 9 | kyabe
# Processing Record 27 of Set 9 | sabang
# Processing Record 28 of Set 9 | ada
# Processing Record 29 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 9 | vallenar
# Processing Record 31 of Set 9 | iracoubo
# Processing Record 32 of Set 9 | berezovyy
# Processing Record 33 of Set 9 | porto novo
# Processing Record 34 of Set 9 | valle de allende
# Processing Record 35 of Set 9 | bonthe
# Processing Record 36 of Set 9 | la ronge
# Processing Record 37 of Set 9 | rundu
# Processing Record 38 of Set 9 | buenos aires
# Processing Record 39 of Set 9 | coihaique
# Processing Record 40 of Set 9 | cusuna
# Processing Record 41 of Set 9 | campobello di mazara
# Processing Record 42 of Set 9 | canon city
# Processing Record 43 of Set 9 | san bartolome de tirajana
# Processing Record 44 of Set 9 | bauchi
# Processing Record 45 of Set 9 | henties bay
# Processing Record 46 of Set 9 | dubai
# Processing Record 47 of Set 9 | road town
# Processing Record 48 of Set 9 | katsikas
# Processing Record 49 of Set 9 | anadyr
# Processing Record 50 of Set 9 | abu kamal
# Processing Record 1 of Set 10 | el rosario
# Processing Record 2 of Set 10 | urusha
# Processing Record 3 of Set 10 | lata
# Processing Record 4 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 10 | cidreira
# Processing Record 6 of Set 10 | vonyarcvashegy
# Processing Record 7 of Set 10 | sobolevo
# Processing Record 8 of Set 10 | kindersley
# Processing Record 9 of Set 10 | sechura
# Processing Record 10 of Set 10 | tual
# Processing Record 11 of Set 10 | touros
# Processing Record 12 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 13 of Set 10 | zhezkazgan
# Processing Record 14 of Set 10 | abu samrah
# Processing Record 15 of Set 10 | nhulunbuy
# Processing Record 16 of Set 10 | westport
# Processing Record 17 of Set 10 | chuy
# Processing Record 18 of Set 10 | kaeo
# Processing Record 19 of Set 10 | kalmunai
# Processing Record 20 of Set 10 | oranjestad
# Processing Record 21 of Set 10 | opuwo
# Processing Record 22 of Set 10 | sorong
# Processing Record 23 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 10 | warragul
# Processing Record 25 of Set 10 | rio grande
# Processing Record 26 of Set 10 | half moon bay
# Processing Record 27 of Set 10 | tungkang
# City not found. Skipping...
# Processing Record 28 of Set 10 | conceicao do araguaia
# Processing Record 29 of Set 10 | mount isa
# Processing Record 30 of Set 10 | jizan
# Processing Record 31 of Set 10 | sobreira
# Processing Record 32 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 33 of Set 10 | chifeng
# Processing Record 34 of Set 10 | jinchang
# Processing Record 35 of Set 10 | mmabatho
# Processing Record 36 of Set 10 | kita
# Processing Record 37 of Set 10 | sur
# Processing Record 38 of Set 10 | nioro
# Processing Record 39 of Set 10 | aksu
# Processing Record 40 of Set 10 | havoysund
# Processing Record 41 of Set 10 | camocim
# Processing Record 42 of Set 10 | diffa
# Processing Record 43 of Set 10 | summerville
# Processing Record 44 of Set 10 | buala
# Processing Record 45 of Set 10 | gat
# Processing Record 46 of Set 10 | namatanai
# Processing Record 47 of Set 10 | kodinsk
# Processing Record 48 of Set 10 | cruzeiro do sul
# Processing Record 49 of Set 10 | trincomalee
# Processing Record 50 of Set 10 | ankang
# Processing Record 1 of Set 11 | benguela
# Processing Record 2 of Set 11 | mersing
# Processing Record 3 of Set 11 | oistins
# Processing Record 4 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 5 of Set 11 | dunda
# Processing Record 6 of Set 11 | verkhnyaya inta
# Processing Record 7 of Set 11 | corralillo
# Processing Record 8 of Set 11 | amapa
# Processing Record 9 of Set 11 | iqaluit
# Processing Record 10 of Set 11 | mantua
# Processing Record 11 of Set 11 | praia da vitoria
# Processing Record 12 of Set 11 | ostfildern
# Processing Record 13 of Set 11 | kingisepp
# Processing Record 14 of Set 11 | mehamn
# Processing Record 15 of Set 11 | kandrian
# Processing Record 16 of Set 11 | cheney
# Processing Record 17 of Set 11 | berlevag
# Processing Record 18 of Set 11 | seoul
# Processing Record 19 of Set 11 | kotovsk
# Processing Record 20 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 21 of Set 11 | erenhot
# Processing Record 22 of Set 11 | maceio
# Processing Record 23 of Set 11 | thana
# Processing Record 24 of Set 11 | bababe
# City not found. Skipping...
# Processing Record 25 of Set 11 | sedelnikovo
# City not found. Skipping...
# Processing Record 26 of Set 11 | tatawin
# Processing Record 27 of Set 11 | singapore
# Processing Record 28 of Set 11 | deputatskiy
# Processing Record 29 of Set 11 | aquiraz
# Processing Record 30 of Set 11 | sao joao da barra
# Processing Record 31 of Set 11 | koslan
# Processing Record 32 of Set 11 | pinheiro machado
# Processing Record 33 of Set 11 | matagami
# Processing Record 34 of Set 11 | matay
# Processing Record 35 of Set 11 | xiaoweizhai
# Processing Record 36 of Set 11 | bisert
# Processing Record 37 of Set 11 | the valley
# Processing Record 38 of Set 11 | moses lake
# Processing Record 39 of Set 11 | quatre cocos
# Processing Record 40 of Set 11 | muli
# Processing Record 41 of Set 11 | great falls
# Processing Record 42 of Set 11 | mahina
# Processing Record 43 of Set 11 | comodoro rivadavia
# Processing Record 44 of Set 11 | nantou
# Processing Record 45 of Set 11 | esil
# Processing Record 46 of Set 11 | lang son
# Processing Record 47 of Set 11 | santa ines
# Processing Record 48 of Set 11 | hofn
# Processing Record 49 of Set 11 | aporawan
# City not found. Skipping...
# Processing Record 50 of Set 11 | vao
# Processing Record 1 of Set 12 | port hawkesbury
# Processing Record 2 of Set 12 | tumpat
# Processing Record 3 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 4 of Set 12 | boa vista
# Processing Record 5 of Set 12 | zhangye
# Processing Record 6 of Set 12 | kyzyl-suu
# Processing Record 7 of Set 12 | hun
# Processing Record 8 of Set 12 | harlingen
# Processing Record 9 of Set 12 | san miguel
# Processing Record 10 of Set 12 | kota kinabalu
# Processing Record 11 of Set 12 | darlowo
# Processing Record 12 of Set 12 | harwich
# Processing Record 13 of Set 12 | kieta
# Processing Record 14 of Set 12 | hay river
# Processing Record 15 of Set 12 | shingu
# Processing Record 16 of Set 12 | naron
# Processing Record 17 of Set 12 | tazovskiy
# Processing Record 18 of Set 12 | aswan
# Processing Record 19 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 12 | ilulissat
# Processing Record 21 of Set 12 | gold coast
# Processing Record 22 of Set 12 | sandy bay
# Processing Record 23 of Set 12 | jieshi
# Processing Record 24 of Set 12 | parkland
# Processing Record 25 of Set 12 | kyra
# Processing Record 26 of Set 12 | tungor
# Processing Record 27 of Set 12 | viedma
# Processing Record 28 of Set 12 | nome
# Processing Record 29 of Set 12 | nantucket
# Processing Record 30 of Set 12 | znamenskoye
# Processing Record 31 of Set 12 | mapiri
# Processing Record 32 of Set 12 | jatibonico
# Processing Record 33 of Set 12 | altay
# Processing Record 34 of Set 12 | clarksdale
# Processing Record 35 of Set 12 | anloga
# Processing Record 36 of Set 12 | colares
# Processing Record 37 of Set 12 | saint anthony
# Processing Record 38 of Set 12 | banmo
# City not found. Skipping...
# Processing Record 39 of Set 12 | hegang
# Processing Record 40 of Set 12 | odweyne
# Processing Record 41 of Set 12 | redwater
# Processing Record 42 of Set 12 | atbasar
# Processing Record 43 of Set 12 | pokaran
# Processing Record 44 of Set 12 | rabo de peixe
# Processing Record 45 of Set 12 | bonavista
# Processing Record 46 of Set 12 | amalapuram
# Processing Record 47 of Set 12 | nikel
# Processing Record 48 of Set 12 | zavetnoye
# Processing Record 49 of Set 12 | shujaabad
# Processing Record 50 of Set 12 | doka
# Processing Record 1 of Set 13 | vilyuysk
# Processing Record 2 of Set 13 | mizdah
# Processing Record 3 of Set 13 | humacao
# Processing Record 4 of Set 13 | yerbogachen
# Processing Record 5 of Set 13 | windhoek
# Processing Record 6 of Set 13 | san carlos
# Processing Record 7 of Set 13 | nanortalik
# Processing Record 8 of Set 13 | staunton
# Processing Record 9 of Set 13 | male
# Processing Record 10 of Set 13 | pemangkat
# Processing Record 11 of Set 13 | killam
# Processing Record 12 of Set 13 | mwinilunga
# Processing Record 13 of Set 13 | bonfim
# Processing Record 14 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 15 of Set 13 | souillac
# Processing Record 16 of Set 13 | igarka
# Processing Record 17 of Set 13 | san javier
# Processing Record 18 of Set 13 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 13 | chuchkovo
# Processing Record 21 of Set 13 | dahanu
# Processing Record 22 of Set 13 | sibolga
# Processing Record 23 of Set 13 | paragominas
# Processing Record 24 of Set 13 | candolim
# Processing Record 25 of Set 13 | ternate
# Processing Record 26 of Set 13 | coahuayana
# Processing Record 27 of Set 13 | nerchinskiy zavod
# Processing Record 28 of Set 13 | am timan
# Processing Record 29 of Set 13 | kavaratti
# Processing Record 30 of Set 13 | kapuskasing
# Processing Record 31 of Set 13 | port victoria
# Processing Record 32 of Set 13 | laem sing
# Processing Record 33 of Set 13 | killybegs
# Processing Record 34 of Set 13 | yar-sale
# Processing Record 35 of Set 13 | hosbach
# Processing Record 36 of Set 13 | havelock
# Processing Record 37 of Set 13 | groningen
# Processing Record 38 of Set 13 | presidencia roque saenz pena
# Processing Record 39 of Set 13 | sheridan
# Processing Record 40 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 13 | kushima
# Processing Record 42 of Set 13 | gizo
# Processing Record 43 of Set 13 | florence
# Processing Record 44 of Set 13 | pangnirtung
# Processing Record 45 of Set 13 | dolores
# Processing Record 46 of Set 13 | samarai
# Processing Record 47 of Set 13 | sekoma
# Processing Record 48 of Set 13 | challans
# Processing Record 49 of Set 13 | dubti
# Processing Record 50 of Set 13 | spring valley
# Processing Record 1 of Set 14 | zhuhai
# Processing Record 2 of Set 14 | suruc
# Processing Record 3 of Set 14 | urubicha
# Processing Record 4 of Set 14 | colombo
# Processing Record 5 of Set 14 | garowe
# Processing Record 6 of Set 14 | merke
# Processing Record 7 of Set 14 | kerman
# Processing Record 8 of Set 14 | houston
# Processing Record 9 of Set 14 | slonim
# Processing Record 10 of Set 14 | ulladulla
# Processing Record 11 of Set 14 | laguna
# Processing Record 12 of Set 14 | veraval
# Processing Record 13 of Set 14 | teeli
# Processing Record 14 of Set 14 | mareeba
# Processing Record 15 of Set 14 | yuxia
# Processing Record 16 of Set 14 | chom bung
# City not found. Skipping...
# Processing Record 17 of Set 14 | monroe
# Processing Record 18 of Set 14 | ketchikan
# Processing Record 19 of Set 14 | norsup
# Processing Record 20 of Set 14 | coari
# Processing Record 21 of Set 14 | yumen
# Processing Record 22 of Set 14 | luchenza
# Processing Record 23 of Set 14 | ilhabela
# Processing Record 24 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 25 of Set 14 | kimbe
# Processing Record 26 of Set 14 | san cristobal
# Processing Record 27 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 28 of Set 14 | ponta delgada
# Processing Record 29 of Set 14 | zehdenick
# Processing Record 30 of Set 14 | bagrami
# Processing Record 31 of Set 14 | saint-francois
# Processing Record 32 of Set 14 | tianpeng
# Processing Record 33 of Set 14 | ankazobe
# Processing Record 34 of Set 14 | kemijarvi
# Processing Record 35 of Set 14 | chicama
# Processing Record 36 of Set 14 | atasu
# Processing Record 37 of Set 14 | nagornskiy
# Processing Record 38 of Set 14 | biak
# Processing Record 39 of Set 14 | nizhnyaya omka
# Processing Record 40 of Set 14 | durango
# Processing Record 41 of Set 14 | bucerias
# Processing Record 42 of Set 14 | pervomayskiy
# Processing Record 43 of Set 14 | tarudant
# City not found. Skipping...
# Processing Record 44 of Set 14 | miramar
# Processing Record 45 of Set 14 | boysun
# Processing Record 46 of Set 14 | moose factory
# Processing Record 47 of Set 14 | seddon
# Processing Record 48 of Set 14 | rocha
# Processing Record 49 of Set 14 | bethlehem
# Processing Record 50 of Set 14 | la rioja
# Processing Record 1 of Set 15 | berekum
# Processing Record 2 of Set 15 | ambilobe
# Processing Record 3 of Set 15 | acarau
# Processing Record 4 of Set 15 | antibes
# Processing Record 5 of Set 15 | lake city
# Processing Record 6 of Set 15 | grafton
# Processing Record 7 of Set 15 | mahon
# Processing Record 8 of Set 15 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 15 | carman
# Processing Record 10 of Set 15 | carire
# Processing Record 11 of Set 15 | nyurba
# Processing Record 12 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 15 | agen
# Processing Record 14 of Set 15 | gurmatkal
# Processing Record 15 of Set 15 | aba
# Processing Record 16 of Set 15 | polunochnoye
# Processing Record 17 of Set 15 | akyab
# Processing Record 18 of Set 15 | torring
# Processing Record 19 of Set 15 | mae sai
# Processing Record 20 of Set 15 | port lincoln
# Processing Record 21 of Set 15 | kutum
# Processing Record 22 of Set 15 | koani
# Processing Record 23 of Set 15 | zhigalovo
# Processing Record 24 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 25 of Set 15 | ios
# Processing Record 26 of Set 15 | palestina
# Processing Record 27 of Set 15 | grindavik
# Processing Record 28 of Set 15 | araouane
# Processing Record 29 of Set 15 | kilmallock
# Processing Record 30 of Set 15 | daru
# Processing Record 31 of Set 15 | rio pomba
# Processing Record 32 of Set 15 | codo
# Processing Record 33 of Set 15 | skegness
# Processing Record 34 of Set 15 | afmadu
# City not found. Skipping...
# Processing Record 35 of Set 15 | fare
# Processing Record 36 of Set 15 | winter park
# Processing Record 37 of Set 15 | inirida
# Processing Record 38 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 39 of Set 15 | vanimo
# Processing Record 40 of Set 15 | san pedro
# Processing Record 41 of Set 15 | along
# Processing Record 42 of Set 15 | christchurch
# Processing Record 43 of Set 15 | batagay-alyta
# Processing Record 44 of Set 15 | uglegorsk
# Processing Record 45 of Set 15 | aromashevo
# Processing Record 46 of Set 15 | vincennes
# Processing Record 47 of Set 15 | mubi
# Processing Record 48 of Set 15 | ginda
# Processing Record 49 of Set 15 | toliary
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng Current Descrition  Max Temp  Humidity  \
# 0         Albany  42.6001  -73.9662      broken clouds     92.80        58
# 1   Norman Wells  65.2820 -126.8329      broken clouds     62.64        77
# 2    Clyde River  70.4692  -68.5914      broken clouds     41.23        93
# 3        Ushuaia -54.8000  -68.3000            drizzle     37.06        93
# 4          Praya  14.9215  -23.5087         few clouds     84.74        54
# 5        Mtsensk  53.2766   36.5733         few clouds     61.27        71
# 6         Urumqi  43.8010   87.6005          clear sky     74.35        41
# 7          Lagoa  39.0500  -27.9833      broken clouds     73.71        79
# 8  Mar Del Plata -38.0023  -57.5575          clear sky     53.62        54
# 9     Nikolskoye  59.7035   30.7861          clear sky     67.01        79
#
#    Cloudiness  Wind Speed Country
# 0          70        7.02      US
# 1          75        4.61      CA
# 2          75       17.27      CA
# 3          75       12.66      AR
# 4          20       13.80      CV
# 5          19        6.06      RU
# 6           0        2.24      CN
# 7          81        1.74      PT
# 8           0       10.36      AR
# 9           2        5.53      RU

# %%
new_column_order = ["City" , "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed",  "Current Descrition"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Albany      US  42.6001  -73.9662     92.80        58          70
# 1   Norman Wells      CA  65.2820 -126.8329     62.64        77          75
# 2    Clyde River      CA  70.4692  -68.5914     41.23        93          75
# 3        Ushuaia      AR -54.8000  -68.3000     37.06        93          75
# 4          Praya      CV  14.9215  -23.5087     84.74        54          20
# 5        Mtsensk      RU  53.2766   36.5733     61.27        71          19
# 6         Urumqi      CN  43.8010   87.6005     74.35        41           0
# 7          Lagoa      PT  39.0500  -27.9833     73.71        79          81
# 8  Mar Del Plata      AR -38.0023  -57.5575     53.62        54           0
# 9     Nikolskoye      RU  59.7035   30.7861     67.01        79           2
#
#    Wind Speed Current Descrition
# 0        7.02      broken clouds
# 1        4.61      broken clouds
# 2       17.27      broken clouds
# 3       12.66            drizzle
# 4       13.80         few clouds
# 5        6.06         few clouds
# 6        2.24          clear sky
# 7        1.74      broken clouds
# 8       10.36          clear sky
# 9        5.53          clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/weatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
